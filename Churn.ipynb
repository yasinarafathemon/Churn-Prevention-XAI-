# %% [markdown]
# <a href="https://colab.research.google.com/github/NishatVasker/University_Projects/blob/master/CSE303_version_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, precision_recall_fscore_support

# Loading the provided dataset
file_path_1 = '/content/DATA IN BRIEF -DATA.xlsx'
survey_data_1 = pd.read_excel(file_path_1)

# Displaying the first few rows of the dataset to understand its structure
survey_data_1.head()
# Out:
# Workbook contains no default style, apply openpyxl's default
#   Variable                Gender                Age  \
# 0    Label  What is your gender?  What is your age?
# 1      NaN                     2                  2
# 2      NaN                     2                  2
# 3      NaN                     2                  2
# 4      NaN                     1                  2
#
#                                            Education  \
# 0  What is your highest level of education comple...
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#                  Occupation                                   City  \
# 0  What is your occupation?  What is your current location. (City)
# 1                         4                                      3
# 2                         1                                      1
# 3                         1                                      1
# 4                         1                                      1
#
#                                       Monthly_Income  \
# 0  What is your monthly household Income?  (In ru...
# 1                                                  3
# 2                                                  2
# 3                                                  1
# 4                                                  2
#
#                                              PK1  \
# 0  Clothing made from organic fibers is stylish.
# 1                                              2
# 2                                              3
# 3                                              3
# 4                                              4
#
#                                                  PK2  \
# 0  Clothing made from organic fibers has attracti...
# 1                                                  2
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#                                              PK3  ...  \
# 0  Clothing made from organic fibers is durable.  ...
# 1                                              3  ...
# 2                                              4  ...
# 3                                              4  ...
# 4                                              4  ...
#
#                                                 MOT4  \
# 0  I believe that clothing made from organic fibe...
# 1                                                  3
# 2                                                  4
# 3                                                  5
# 4                                                  4
#
#                                                   P1  \
# 0  I am willing to pay more for clothing from env...
# 1                                                  1
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#                                                   P2  \
# 0  In the future, I intend to purchase environmen...
# 1                                                  2
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#                                                   P3  \
# 0  I would consider buying environmentally friend...
# 1                                                  3
# 2                                                  4
# 3                                                  5
# 4                                                  4
#
#                                                   P4  \
# 0  I would consider switching to environmentally ...
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#                                                  BB1  \
# 0  When I have a choice between two similar cloth...
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#                                                  BB2  \
# 0  I prioritize selecting apparel that can be wor...
# 1                                                  2
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#                                                  BB3  \
# 0  I prefer to buy clothing made of organically g...
# 1                                                  2
# 2                                                  4
# 3                                                  5
# 4                                                  4
#
#                                                  BB4  Total
# 0  I prefer to buy apparel that has environmental...    NaN
# 1                                                  3   67.0
# 2                                                  4  103.0
# 3                                                  5  116.0
# 4                                                  4  115.0
#
# [5 rows x 36 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Total'].plot(kind='hist', bins=20, title='Total')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Variable').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('Age').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Education').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['Total'].plot(kind='line', figsize=(8, 4), title='Total')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Gender'].value_counts()
#     for x_label, grp in _df_6.groupby('Variable')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Variable')
# _ = plt.ylabel('Gender')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Age'].value_counts()
#     for x_label, grp in _df_7.groupby('Gender')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Gender')
# _ = plt.ylabel('Age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Education'].value_counts()
#     for x_label, grp in _df_8.groupby('Age')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Age')
# _ = plt.ylabel('Education')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Occupation'].value_counts()
#     for x_label, grp in _df_9.groupby('Education')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Education')
# _ = plt.ylabel('Occupation')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_10['Variable'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_10, x='Total', y='Variable', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_11['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_11, x='Total', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_12['Age'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_12, x='Total', y='Age', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['Education'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='Total', y='Education', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
_df_5['Total'].plot(kind='line', figsize=(8, 4), title='Total')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_4.groupby('Education').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_3.groupby('Age').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_2.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['Total'].plot(kind='hist', bins=20, title='Total')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, precision_recall_fscore_support

# Loading the provided dataset
file_path_1 = '/content/Response.xlsx'
survey_data_1 = pd.read_excel(file_path_1)

# Displaying the first few rows of the dataset to understand its structure
survey_data_1.head()
# Out:
#     QA 1: What is your gender?   What is your age?   \
# 0                             2                   2
# 1                             2                   2
# 2                             2                   2
# 3                             1                   2
# 4                             2                   2
#
#    What is your highest level of education completed?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    What is your occupation?  What is your current location. (City)   \
# 0                         4                                       3
# 1                         1                                       1
# 2                         1                                       1
# 3                         1                                       1
# 4                         1                                       1
#
#    What is your monthly household Income?  (In rupees)  \
# 0                                                  3
# 1                                                  2
# 2                                                  1
# 3                                                  2
# 4                                                  3
#
#    B1 Product Knowledge [Clothing made from organic fibers is stylish.]  \
# 0                                                  2
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  3
#
#    B1 Product Knowledge [Clothing made from organic fibers has attractive designs.]  \
# 0                                                  2
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    B1 Product Knowledge [Clothing made from organic fibers is durable.]  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    B1 Product Knowledge [Clothing made from organic fibers has good quality.]  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    B5 Motivation [I believe that clothing made from organic fibers is beneficial for my skin.]  \
# 0                                                  3
# 1                                                  4
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#    B6 Purchase Intention [I am willing to pay more for clothing from environmentally and/or socially responsible clothing brands.]  \
# 0                                                  1
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    B6 Purchase Intention [In the future, I intend to purchase environmentally sustainable apparel.]  \
# 0                                                  2
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  2
#
#    B6 Purchase Intention [I would consider buying environmentally friendly apparel because it is less polluting.]  \
# 0                                                  3
# 1                                                  4
# 2                                                  5
# 3                                                  4
# 4                                                  3
#
#    B6 Purchase Intention [I would consider switching to environmentally friendly apparel brands for ecological reasons.]  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    B7 Buying Behaviour [When I have a choice between two similar clothing items, I prefer to purchase the one made from textile materials that are less harmful to the environment.]  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    B7 Buying Behaviour [I prioritize selecting apparel that can be worn over a longer term compared to trendy apparel that goes out of style quickly.]  \
# 0                                                  2
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    B7 Buying Behaviour [I prefer to buy clothing made of organically grown natural fibers.]  \
# 0                                                  2
# 1                                                  4
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#    B7 Buying Behaviour [I prefer to buy apparel that has environmentally friendly labeling or packaging techniques.]  \
# 0                                                  3
# 1                                                  4
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#    Unnamed: 34
# 0           83
# 1          113
# 2          196
# 3          124
# 4          101
#
# [5 rows x 35 columns]
# Warning: Total number of columns (35) exceeds max_columns (20) limiting to first (20) columns.
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_43['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_44[' QA 1: What is your gender? '].plot(kind='hist', bins=20, title=' QA 1: What is your gender? ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_45['What is your occupation?'].plot(kind='hist', bins=20, title='What is your occupation?')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_46['What is your current location. (City) '].plot(kind='hist', bins=20, title='What is your current location. (City) ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_47.plot(kind='scatter', x='index', y=' QA 1: What is your gender? ', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_48.plot(kind='scatter', x=' QA 1: What is your gender? ', y='What is your occupation?', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_49.plot(kind='scatter', x='What is your occupation?', y='What is your current location. (City) ', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_50.plot(kind='scatter', x='What is your current location. (City) ', y='What is your monthly household Income?  (In rupees)', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series[' QA 1: What is your gender? ']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_51.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel(' QA 1: What is your gender? ')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['What is your occupation?']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_52.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('What is your occupation?')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['What is your current location. (City) ']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_53.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('What is your current location. (City) ')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['What is your monthly household Income?  (In rupees)']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_54.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('What is your monthly household Income?  (In rupees)')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_55['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_56[' QA 1: What is your gender? '].plot(kind='line', figsize=(8, 4), title=' QA 1: What is your gender? ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_57['What is your occupation?'].plot(kind='line', figsize=(8, 4), title='What is your occupation?')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_58['What is your current location. (City) '].plot(kind='line', figsize=(8, 4), title='What is your current location. (City) ')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_17['What is your monthly household Income?  (In rupees)'].plot(kind='hist', bins=20, title='What is your monthly household Income?  (In rupees)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_16['What is your current location. (City) '].plot(kind='hist', bins=20, title='What is your current location. (City) ')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_15['What is your occupation?'].plot(kind='hist', bins=20, title='What is your occupation?')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_14[' QA 1: What is your gender? '].plot(kind='hist', bins=20, title=' QA 1: What is your gender? ')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, precision_recall_fscore_support

# Loading the provided dataset
file_path_1 = '/content/Scale Development and Item generation.xlsx'
survey_data_1 = pd.read_excel(file_path_1)

# Displaying the first few rows of the dataset to understand its structure
survey_data_1.head()
# Out:
#                 Construct                                      Adapted Items   \
# 0  Enviornmental Knowledge  Dyeing and finishing processes used to produce...
# 1                      NaN  The manufacturing process of synthetic or manu...
# 2                      NaN  Chemicals used in textile processing can remai...
# 3                      NaN  I am aware of the environmental impact caused ...
# 4          Percieved value  This sustainable clothing is well made and wor...
#
#                                           Source
# 0            Hye Jung Jung & Kyung Wha Oh (2019)
# 1                            Jung et al., (2021)
# 2  Hayat Alboloushi & Kim Y. Hiller Connel(2022)
# 3                        Park, S & Lee, Y (2020)
# 4             Pei-Hsin Lin & Wun-Hwa Chen (2022)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_30['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_31.groupby('Construct ').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_32.groupby('Adapted Items ').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_33.groupby('Source').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_34.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Construct ')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Construct ', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_35.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Adapted Items ')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Adapted Items ', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_36.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Source')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Source', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_37['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Adapted Items '].value_counts()
#     for x_label, grp in _df_38.groupby('Construct ')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Construct ')
# _ = plt.ylabel('Adapted Items ')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Source'].value_counts()
#     for x_label, grp in _df_39.groupby('Adapted Items ')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Adapted Items ')
# _ = plt.ylabel('Source')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_40['Construct '].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_40, x='index', y='Construct ', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_41['Adapted Items '].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_41, x='index', y='Adapted Items ', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_42['Source'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_42, x='index', y='Source', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_33.groupby('Source').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_32.groupby('Adapted Items ').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_31.groupby('Construct ').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



# Assuming your dataset is in a CSV file named 'your_dataset.csv'
df = pd.read_csv('/content/csv/DATA IN BRIEF -DATA.csv')



# Display basic information about the dataset
df.info()

# Display summary statistics
df.describe()

# Check for missing values
df.isnull().sum()

# Visualize data distribution
sns.pairplot(df)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 36 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Variable        1 non-null      object
#  1   Gender          41 non-null     object
#  2   Age             41 non-null     object
#  3   Education       41 non-null     object
#  4   Occupation      41 non-null     object
#  5   City            41 non-null     object
#  6   Monthly_Income  41 non-null     object
#  7   PK1             41 non-null     object
#  8   PK2             41 non-null     object
#  9   PK3             41 non-null     object
#  10  PK4             41 non-null     object
#  11  CA1             41 non-null     object
#  12  CA2             41 non-null     object
#  13  CA3             41 non-null     object
#  14  CA4             41 non-null     object
#  15  EA1             41 non-null     object
#  16  EA2             41 non-null     object
#  17  EA3             41 non-null     object
#  18  EA4             41 non-null     object
#  19  PV1             41 non-null     object
#  20  PV2             41 non-null     object
#  21  PV3             41 non-null     object
#  22  PV4             41 non-null     object
#  23  MOT1            41 non-null     object
#  24  MOT2            41 non-null     object
#  25  MOT3            41 non-null     object
#  26  MOT4            41 non-null     object
#  27  P1              41 non-null     object
#  28  P2              41 non-null     object
#  29  P3              41 non-null     object
#  30  P4              41 non-null     object
#  31  BB1             41 non-null     object
#  32  BB2             41 non-null     object
#  33  BB3             41 non-null     object
#  34  BB4             41 non-null     object
#  35  Total           40 non-null     float64
# dtypes: float64(1), object(35)
# memory usage: 11.7+ KB

# %%
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, f_oneway
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the dataset
file_path = '/content/DATA IN BRIEF -DATA.xlsx'
survey_data = pd.read_excel(file_path)

# Convert survey responses to numeric for analysis
response_columns = survey_data.columns[7:]  # Assuming survey responses start from the 8th column
for col in response_columns:
    survey_data[col] = pd.to_numeric(survey_data[col], errors='coerce')

# Correlation Analysis
# Calculate correlations for all pairs of survey response variables
correlation_matrix = survey_data[response_columns].corr()

# Creating a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap of Survey Responses')
plt.show()

# Regression Analysis
# Example: Predicting 'BB1' from 'PK1', 'CA1', 'EA1', etc.
y = survey_data['BB1'].dropna()
X = survey_data[['PK1', 'PK2', 'PK3', 'PK4', 'CA1', 'CA2', 'CA3', 'CA4', 'EA1', 'EA2',
       'EA3', 'EA4', 'PV1', 'PV2', 'PV3', 'PV4', 'MOT1', 'MOT2', 'MOT3',
       'MOT4', 'P1', 'P2', 'P3', 'P4', 'BB2', 'BB3', 'BB4']].dropna()  # Removed 'BB1' from X as this is feature
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

# Displaying the regression summary table
print(model.summary())


# Plotting the regression results for 'PK1'
plt.figure(figsize=(8, 6))
sns.regplot(x='PK1', y='BB1', data=survey_data, scatter_kws={'alpha':0.5})
plt.title('Regression Analysis: PK1 vs BB1')
plt.xlabel('Product Knowledge (PK1)')
plt.ylabel('Buying Behavior (BB1)')
plt.show()

# Displaying the regression summary table
print(model.summary())

# ANOVA Analysis across Age groups for 'BB1'
anova_result = f_oneway(*[survey_data[survey_data['Age'] == age]['BB1'].dropna() for age in survey_data['Age'].unique() if not pd.isna(age)])

# Printing the ANOVA results
print(f"ANOVA F-statistic: {anova_result.statistic}")
print(f"ANOVA P-value: {anova_result.pvalue}")

# Machine Learning Model: Decision Tree Classifier
# Predicting 'BB1' using multiple features
features = ['PK1', 'CA1', 'EA1', 'PV1', 'MOT1', 'P1']
X = survey_data[features].dropna()
y = survey_data.loc[X.index, 'BB1']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

# Printing the accuracy of the Decision Tree model
print(f"Accuracy of the Decision Tree model: {accuracy}")
# Out:
# Workbook contains no default style, apply openpyxl's default
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BB1   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     7.733
# Date:                Thu, 07 Dec 2023   Prob (F-statistic):           0.000321
# Time:                        16:40:11   Log-Likelihood:                -5.9087
# No. Observations:                  40   AIC:                             67.82
# Df Residuals:                      12   BIC:                             115.1
# Df Model:                          27
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3869      0.666     -0.581      0.572      -1.839       1.065
# PK1            0.1651      0.229      0.720      0.485      -0.335       0.665
# PK2           -0.3819      0.301     -1.271      0.228      -1.037       0.273
# PK3            0.4790      0.420      1.142      0.276      -0.435       1.393
# PK4           -0.0688      0.365     -0.188      0.854      -0.864       0.727
# CA1            0.3609      0.134      2.700      0.019       0.070       0.652
# CA2           -0.2433      0.207     -1.176      0.262      -0.694       0.207
# CA3           -0.2610      0.187     -1.394      0.188      -0.669       0.147
# CA4            0.1211      0.251      0.482      0.638      -0.426       0.668
# EA1           -0.3372      0.300     -1.125      0.282      -0.990       0.316
# EA2            0.2721      0.326      0.835      0.420      -0.438       0.982
# EA3           -0.4218      0.312     -1.350      0.202      -1.102       0.259
# EA4            0.9389      0.273      3.443      0.005       0.345       1.533
# PV1            0.0167      0.374      0.045      0.965      -0.799       0.832
# PV2            0.8516      0.334      2.546      0.026       0.123       1.580
# PV3           -1.0979      0.368     -2.985      0.011      -1.899      -0.296
# PV4            0.1655      0.343      0.483      0.638      -0.582       0.912
# MOT1           0.3366      0.184      1.831      0.092      -0.064       0.737
# MOT2           0.0578      0.163      0.354      0.729      -0.298       0.414
# MOT3          -0.2541      0.219     -1.161      0.268      -0.731       0.223
# MOT4          -0.1505      0.215     -0.699      0.498      -0.619       0.318
# P1             0.0289      0.204      0.141      0.890      -0.416       0.474
# P2            -0.3747      0.324     -1.158      0.270      -1.080       0.330
# P3             0.5515      0.311      1.775      0.101      -0.126       1.229
# P4             0.1640      0.387      0.424      0.679      -0.679       1.007
# BB2            0.6598      0.651      1.014      0.331      -0.758       2.077
# BB3           -0.8147      0.538     -1.513      0.156      -1.988       0.358
# BB4            0.2886      0.307      0.939      0.366      -0.381       0.958
# ==============================================================================
# Omnibus:                        1.626   Durbin-Watson:                   1.249
# Prob(Omnibus):                  0.444   Jarque-Bera (JB):                1.229
# Skew:                          -0.198   Prob(JB):                        0.541
# Kurtosis:                       2.238   Cond. No.                         265.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BB1   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     7.733
# Date:                Thu, 07 Dec 2023   Prob (F-statistic):           0.000321
# Time:                        16:40:12   Log-Likelihood:                -5.9087
# No. Observations:                  40   AIC:                             67.82
# Df Residuals:                      12   BIC:                             115.1
# Df Model:                          27
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3869      0.666     -0.581      0.572      -1.839       1.065
# PK1            0.1651      0.229      0.720      0.485      -0.335       0.665
# PK2           -0.3819      0.301     -1.271      0.228      -1.037       0.273
# PK3            0.4790      0.420      1.142      0.276      -0.435       1.393
# PK4           -0.0688      0.365     -0.188      0.854      -0.864       0.727
# CA1            0.3609      0.134      2.700      0.019       0.070       0.652
# CA2           -0.2433      0.207     -1.176      0.262      -0.694       0.207
# CA3           -0.2610      0.187     -1.394      0.188      -0.669       0.147
# CA4            0.1211      0.251      0.482      0.638      -0.426       0.668
# EA1           -0.3372      0.300     -1.125      0.282      -0.990       0.316
# EA2            0.2721      0.326      0.835      0.420      -0.438       0.982
# EA3           -0.4218      0.312     -1.350      0.202      -1.102       0.259
# EA4            0.9389      0.273      3.443      0.005       0.345       1.533
# PV1            0.0167      0.374      0.045      0.965      -0.799       0.832
# PV2            0.8516      0.334      2.546      0.026       0.123       1.580
# PV3           -1.0979      0.368     -2.985      0.011      -1.899      -0.296
# PV4            0.1655      0.343      0.483      0.638      -0.582       0.912
# MOT1           0.3366      0.184      1.831      0.092      -0.064       0.737
# MOT2           0.0578      0.163      0.354      0.729      -0.298       0.414
# MOT3          -0.2541      0.219     -1.161      0.268      -0.731       0.223
# MOT4          -0.1505      0.215     -0.699      0.498      -0.619       0.318
# P1             0.0289      0.204      0.141      0.890      -0.416       0.474
# P2            -0.3747      0.324     -1.158      0.270      -1.080       0.330
# P3             0.5515      0.311      1.775      0.101      -0.126       1.229
# P4             0.1640      0.387      0.424      0.679      -0.679       1.007
# BB2            0.6598      0.651      1.014      0.331      -0.758       2.077
# BB3           -0.8147      0.538     -1.513      0.156      -1.988       0.358
# BB4            0.2886      0.307      0.939      0.366      -0.381       0.958
# ==============================================================================
# Omnibus:                        1.626   Durbin-Watson:                   1.249
# Prob(Omnibus):                  0.444   Jarque-Bera (JB):                1.229
# Skew:                          -0.198   Prob(JB):                        0.541
# Kurtosis:                       2.238   Cond. No.                         265.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ANOVA F-statistic: nan
# ANOVA P-value: nan
# Accuracy of the Decision Tree model: 0.5833333333333334
# at least one input has length 0

# %%
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, f_oneway, chi2_contingency
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report

# Load the dataset
file_path = '/content/DATA IN BRIEF -DATA.xlsx'
survey_data = pd.read_excel(file_path)

# Convert survey responses to numeric for analysis
response_columns = survey_data.columns[7:]  # Assuming survey responses start from the 8th column
for col in response_columns:
    survey_data[col] = pd.to_numeric(survey_data[col], errors='coerce')

# Descriptive Statistics
print("Descriptive Statistics:")
print(survey_data.describe())

# Boxplots for Variable Distributions
plt.figure(figsize=(10,7))
sns.boxplot(data=survey_data[response_columns])
plt.title('Boxplot of Survey Responses')
plt.xticks(rotation=90)
plt.show()

# Correlation Analysis with Heatmap
correlation_matrix = survey_data[response_columns].corr()
plt.figure(figsize=(20, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap of Survey Responses')
plt.show()

# Regression Analysis
# Predicting 'BB1' from selected variables
y = survey_data['BB1'].dropna()
X = survey_data[['PK1', 'CA1', 'EA1', 'PV1', 'MOT1']].dropna()
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print("Regression Analysis Summary:")
print(model.summary())

# Decision Tree Model with Visualization
features = ['PK1', 'CA1', 'EA1', 'PV1', 'MOT1']
X = survey_data[features].dropna()
y = survey_data.loc[X.index, 'BB1']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("Decision Tree Model Performance:")
print(classification_report(y_test, y_pred))

# Plotting the Decision Tree
plt.figure(figsize=(20, 10))
plot_tree(clf, feature_names=features, class_names=True, filled=True)
plt.title('Decision Tree Visualization')
plt.show()
# Out:
# Workbook contains no default style, apply openpyxl's default
# Descriptive Statistics:
#              PK1        PK2        PK3        PK4        CA1       CA2  \
# count  40.000000  40.000000  40.000000  40.000000  40.000000  40.00000
# mean    3.300000   3.400000   3.725000   3.875000   3.300000   3.57500
# std     1.042679   0.871191   0.905468   1.017476   1.343551   1.19588
# min     1.000000   2.000000   2.000000   1.000000   1.000000   1.00000
# 25%     2.750000   3.000000   3.000000   3.000000   2.000000   3.00000
# 50%     3.000000   3.000000   4.000000   4.000000   3.000000   4.00000
# 75%     4.000000   4.000000   4.000000   5.000000   5.000000   5.00000
# max     5.000000   5.000000   5.000000   5.000000   5.000000   5.00000
#
#              CA3        CA4        EA1        EA2  ...       MOT4         P1  \
# count  40.000000  40.000000  40.000000  40.000000  ...  40.000000  40.000000
# mean    3.525000   3.750000   3.600000   3.600000  ...   3.625000   3.425000
# std     1.260596   1.149136   1.057331   1.256777  ...   1.169867   1.278771
# min     1.000000   1.000000   2.000000   1.000000  ...   1.000000   1.000000
# 25%     2.750000   3.000000   3.000000   3.000000  ...   3.000000   2.750000
# 50%     4.000000   4.000000   4.000000   4.000000  ...   4.000000   3.000000
# 75%     5.000000   5.000000   4.250000   5.000000  ...   5.000000   5.000000
# max     5.000000   5.000000   5.000000   5.000000  ...   5.000000   5.000000
#
#               P2         P3         P4        BB1       BB2        BB3  \
# count  40.000000  40.000000  40.000000  40.000000  40.00000  40.000000
# mean    3.700000   3.800000   3.700000   3.550000   3.62500   3.675000
# std     1.159133   1.136797   1.285022   1.218448   1.23387   1.206553
# min     1.000000   1.000000   1.000000   1.000000   1.00000   1.000000
# 25%     3.000000   3.000000   3.000000   3.000000   3.00000   3.000000
# 50%     4.000000   4.000000   4.000000   3.500000   4.00000   4.000000
# 75%     5.000000   5.000000   5.000000   5.000000   5.00000   5.000000
# max     5.000000   5.000000   5.000000   5.000000   5.00000   5.000000
#
#             BB4       Total
# count  40.00000   40.000000
# mean    3.67500  100.000000
# std     1.22762   25.094692
# min     1.00000   42.000000
# 25%     3.00000   82.500000
# 50%     4.00000  102.500000
# 75%     5.00000  120.500000
# max     5.00000  140.000000
#
# [8 rows x 29 columns]
# Regression Analysis Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BB1   R-squared:                       0.531
# Model:                            OLS   Adj. R-squared:                  0.462
# Method:                 Least Squares   F-statistic:                     7.701
# Date:                Thu, 07 Dec 2023   Prob (F-statistic):           6.26e-05
# Time:                        17:10:16   Log-Likelihood:                -49.009
# No. Observations:                  40   AIC:                             110.0
# Df Residuals:                      34   BIC:                             120.2
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0941      0.636     -0.148      0.883      -1.388       1.199
# PK1            0.2157      0.173      1.248      0.221      -0.136       0.567
# CA1            0.1443      0.140      1.029      0.311      -0.141       0.429
# EA1            0.4440      0.162      2.740      0.010       0.115       0.773
# PV1            0.1841      0.166      1.108      0.276      -0.154       0.522
# MOT1           0.0614      0.159      0.386      0.702      -0.262       0.385
# ==============================================================================
# Omnibus:                        3.347   Durbin-Watson:                   1.601
# Prob(Omnibus):                  0.188   Jarque-Bera (JB):                2.343
# Skew:                          -0.573   Prob(JB):                        0.310
# Kurtosis:                       3.300   Cond. No.                         36.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Decision Tree Model Performance:
#               precision    recall  f1-score   support
#
#          2.0       0.50      0.33      0.40         3
#          3.0       0.50      0.33      0.40         3
#          4.0       0.20      1.00      0.33         1
#          5.0       0.33      0.20      0.25         5
#
#     accuracy                           0.33        12
#    macro avg       0.38      0.47      0.35        12
# weighted avg       0.41      0.33      0.33        12

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.44.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.2)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.58.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)

# %%
# Dropping the first row which contains question labels
survey_data = survey_data_1.drop(index=0)

# Converting all columns to numeric, assuming all responses are numeric
survey_data = survey_data.apply(pd.to_numeric, errors='coerce')

# Choosing the last column as the target variable for demonstration (adjust as needed)
target_column = survey_data.columns[-2]  # Assuming the second last column is the target variable
feature_columns = survey_data.columns[7:-2]  # Excluding demographic and target columns for features

# Descriptive Statistics
print("Descriptive Statistics:")
print(survey_data.describe())
# Out:
# Descriptive Statistics:
#        Construct   Adapted Items   Source
# count         0.0             0.0     0.0
# mean          NaN             NaN     NaN
# std           NaN             NaN     NaN
# min           NaN             NaN     NaN
# 25%           NaN             NaN     NaN
# 50%           NaN             NaN     NaN
# 75%           NaN             NaN     NaN
# max           NaN             NaN     NaN

# %%
# Boxplots for Variable Distributions
plt.figure(figsize=(20, 10))
sns.boxplot(data=survey_data[feature_columns])
plt.title('Boxplot of Survey Responses')
plt.xticks(rotation=90)
plt.show()

# %%
# Correlation Analysis with Heatmap
correlation_matrix = survey_data[feature_columns].corr()
plt.figure(figsize=(20, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap of Survey Responses')
plt.show()

# %%
# Regression Analysis
# Dropping rows with NaN values for regression analysis
cleaned_data = survey_data.dropna(subset=[target_column] + list(feature_columns))
y = cleaned_data[target_column]
X = cleaned_data[feature_columns]
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print("Regression Analysis Summary:")
print(model.summary())
# Out:
# Regression Analysis Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BB4   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     9.654
# Date:                Thu, 07 Dec 2023   Prob (F-statistic):           0.000101
# Time:                        17:01:47   Log-Likelihood:                -1.9871
# No. Observations:                  40   AIC:                             59.97
# Df Residuals:                      12   BIC:                             107.3
# Df Model:                          27
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6458      0.583      1.107      0.290      -0.625       1.917
# PK1           -0.4035      0.178     -2.272      0.042      -0.791      -0.017
# PK2            0.6093      0.231      2.640      0.022       0.106       1.112
# PK3           -0.2876      0.392     -0.734      0.477      -1.141       0.566
# PK4            0.0701      0.331      0.212      0.836      -0.651       0.791
# CA1            0.0268      0.153      0.175      0.864      -0.308       0.361
# CA2            0.0137      0.198      0.069      0.946      -0.418       0.445
# CA3            0.1798      0.175      1.025      0.326      -0.202       0.562
# CA4            0.2171      0.221      0.982      0.345      -0.264       0.699
# EA1           -0.1428      0.283     -0.505      0.623      -0.759       0.473
# EA2            0.2464      0.295      0.834      0.420      -0.397       0.890
# EA3           -0.3468      0.287     -1.208      0.250      -0.972       0.279
# EA4           -0.3523      0.333     -1.057      0.312      -1.079       0.374
# PV1            0.6339      0.286      2.218      0.047       0.011       1.257
# PV2            0.1155      0.375      0.308      0.763      -0.701       0.932
# PV3           -0.0212      0.440     -0.048      0.962      -0.980       0.938
# PV4           -0.4806      0.282     -1.707      0.114      -1.094       0.133
# MOT1          -0.0468      0.188     -0.249      0.808      -0.456       0.363
# MOT2          -0.1349      0.144     -0.939      0.366      -0.448       0.178
# MOT3           0.2830      0.193      1.469      0.168      -0.137       0.703
# MOT4           0.1291      0.196      0.660      0.521      -0.297       0.555
# P1            -0.1062      0.183     -0.581      0.572      -0.504       0.292
# P2            -0.1262      0.307     -0.411      0.688      -0.796       0.543
# P3            -0.2670      0.307     -0.870      0.402      -0.936       0.402
# P4            -0.1700      0.350     -0.486      0.636      -0.933       0.593
# BB1            0.2372      0.253      0.939      0.366      -0.313       0.788
# BB2            0.9366      0.552      1.697      0.115      -0.266       2.139
# BB3            0.0411      0.532      0.077      0.940      -1.119       1.201
# ==============================================================================
# Omnibus:                        2.699   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.259   Jarque-Bera (JB):                2.513
# Skew:                           0.559   Prob(JB):                        0.285
# Kurtosis:                       2.491   Cond. No.                         270.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Decision Tree Model
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
# Graph of Precision, Recall, F1-Score, and Accuracy
metrics_data = {
    'Precision': precision,
    'Recall': recall,
    'F1-Score': f1_score,
    'Accuracy': accuracy
}

plt.figure(figsize=(10, 5))
plt.bar(metrics_data.keys(), metrics_data.values())
plt.title('Precision, Recall, F1-Score, and Accuracy of Decision Tree Model')
plt.ylim(0, 1)
plt.ylabel('Score')
plt.show()

# Outputs of each metric
metrics_data
# Out:
# {'Precision': 0.5833333333333334,
#  'Recall': 0.5833333333333334,
#  'F1-Score': 0.5833333333333334,
#  'Accuracy': 0.6666666666666666}

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, f_oneway
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Loading the dataset
file_path_converted = '/content/DATA IN BRIEF -DATA.xlsx'
survey_data = pd.read_excel(file_path_converted)

# Preprocessing: converting relevant columns to numeric for analysis
numeric_columns = ['PK1', 'BB1']  # Add more columns as needed
for col in numeric_columns:
    survey_data[col] = pd.to_numeric(survey_data[col], errors='coerce')

# Correlation Analysis
# Selecting a subset of variables for correlation
subset = survey_data[numeric_columns]
correlation_matrix = subset.corr()

# Creating a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# Regression Analysis
y = survey_data['BB1'].dropna()
X = survey_data.loc[y.index, 'PK1']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

# Plotting the regression results
plt.figure(figsize=(8, 6))
sns.regplot(x='PK1', y='BB1', data=survey_data, scatter_kws={'alpha':0.5})
plt.title('Regression Analysis: PK1 vs BB1')
plt.xlabel('Product Knowledge (PK1)')
plt.ylabel('Buying Behavior (BB1)')
plt.show()

# Displaying the regression summary table
print(model.summary())

# ANOVA Analysis
unique_ages = survey_data['Age'].dropna().unique()
groups = [survey_data[survey_data['Age'] == age]['BB1'].dropna() for age in unique_ages if age != 'What is your age?']
anova_result = f_oneway(*groups)

# Printing the ANOVA results
print(f"ANOVA F-statistic: {anova_result.statistic}")
print(f"ANOVA P-value: {anova_result.pvalue}")

# Machine Learning Model: Decision Tree Classifier
# Predicting 'BB1' using 'PK1' (simplified model)
X = survey_data[['PK1']].dropna()
y = survey_data.loc[X.index, 'BB1']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy of the Decision Tree model: {accuracy}")
# Out:
# Workbook contains no default style, apply openpyxl's default
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BB1   R-squared:                       0.243
# Model:                            OLS   Adj. R-squared:                  0.223
# Method:                 Least Squares   F-statistic:                     12.17
# Date:                Thu, 07 Dec 2023   Prob (F-statistic):            0.00125
# Time:                        17:10:40   Log-Likelihood:                -58.599
# No. Observations:                  40   AIC:                             121.2
# Df Residuals:                      38   BIC:                             124.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.6509      0.570      2.895      0.006       0.496       2.806
# PK1            0.5755      0.165      3.488      0.001       0.241       0.909
# ==============================================================================
# Omnibus:                        0.132   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.936   Jarque-Bera (JB):                0.211
# Skew:                          -0.123   Prob(JB):                        0.900
# Kurtosis:                       2.743   Cond. No.                         12.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ANOVA F-statistic: 1.6362616822429907
# ANOVA P-value: 0.1981004198215377
# Accuracy of the Decision Tree model: 0.25
